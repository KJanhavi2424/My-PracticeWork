# %% [markdown]
# # Pandas

# %%
#Importing necessary libraries
import pandas as pd

# %%
#Series Creation
lst=[21,32,43,54,65,76,87]
type(lst)
# Out:
# list

# %%
pd.Series(lst)
# Out:
# 0    21
# 1    32
# 2    43
# 3    54
# 4    65
# 5    76
# 6    87
# dtype: int64

# %%
#List Method
Series=pd.Series(lst)
type(Series)
# Out:
# pandas.core.series.Series

# %%
#Dictionary Method
d={1:10,2:20,3:30}
type(d)
# Out:
# dict

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
#Series Method
Series= pd.Series(data=['Python','Pune',101],index=['a','b','c'],name='Series')

# %%
#Accessing elements from a Series using index labels

# %%
Series
# Out:
# a    Python
# b      Pune
# c       101
# Name: Series, dtype: object

# %%
Series['b']
# Out:
# 'Pune'

# %%
Series[1]
# Out:
# 'Pune'

# %%
a = [['Python',98,'Pune'],['ML',87,'Mumbai']]
colname = ['Subject','Marks of students','Location']

# %%
pd.DataFrame(data=a, columns=colname)
# Out:
#   Subject  Marks of students Location
# 0  Python                 98     Pune
# 1      ML                 87   Mumbai

# %%
#Approach
df= pd.DataFrame({
    'Subject':['Python','ML','DL'],
    'Marks of students':[10,30,50],
    'Location':['Pune','Mumbai','Hyd']
})

# %%
df
# Out:
#   Subject  Marks of students Location
# 0  Python                 10     Pune
# 1      ML                 30   Mumbai
# 2      DL                 50      Hyd

# %%
#Check number of rows and columns in Dataframe
df.shape
# Out:
# (3, 3)

# %%
#Dimension of the dataframe
df.ndim
# Out:
# 2

# %%
#Data type of each column
df.dtypes
# Out:
# Subject              object
# Marks of students     int64
# Location             object
# dtype: object

# %%
#Extracting columns from Dataframe
df.Subject
# Out:
# 0    Python
# 1        ML
# 2        DL
# Name: Subject, dtype: object

# %%
df[['Marks of students']]
# Out:
#    Marks of students
# 0                 10
# 1                 30
# 2                 50

# %%
#Describe stats for df
df.describe()
# Out:
#        Marks of students
# count                3.0
# mean                30.0
# std                 20.0
# min                 10.0
# 25%                 20.0
# 50%                 30.0
# 75%                 40.0
# max                 50.0

# %%
df.describe(include= object)
# Out:
#        Subject Location
# count        3        3
# unique       3        3
# top     Python     Pune
# freq         1        1

# %%
df.describe(include= 'all')
# Out:
#        Subject  Marks of students Location
# count        3                3.0        3
# unique       3                NaN        3
# top     Python                NaN     Pune
# freq         1                NaN        1
# mean       NaN               30.0      NaN
# std        NaN               20.0      NaN
# min        NaN               10.0      NaN
# 25%        NaN               20.0      NaN
# 50%        NaN               30.0      NaN
# 75%        NaN               40.0      NaN
# max        NaN               50.0      NaN

# %%
#Getting information about the Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Subject            3 non-null      object
#  1   Marks of students  3 non-null      int64
#  2   Location           3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
#checking null values
df.isna()
# Out:
#    Subject  Marks of students  Location
# 0    False              False     False
# 1    False              False     False
# 2    False              False     False

# %%
df.isna().sum()
# Out:
# Subject              0
# Marks of students    0
# Location             0
# dtype: int64

# %% [markdown]
# # Importing External Dataset

# %%
#Load the csv file
df= pd.read_csv('Salaries.csv')
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#Reading first five records
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df.head(10)
# Out:
#         rank discipline  phd  service gender  salary
# 0       Prof          B   56       49   Male  186960
# 1       Prof          A   12        6   Male   93000
# 2       Prof          A   23       20   Male  110515
# 3       Prof          A   40       31   Male  131205
# 4       Prof          B   20       18   Male  104800
# 5       Prof          A   20       20   Male  122400
# 6  AssocProf          A   20       17   Male   81285
# 7       Prof          A   18       18   Male  126300
# 8       Prof          A   29       19   Male   94350
# 9       Prof          A   51       51   Male   57800

# %%
df.tail()
# Out:
#          rank discipline  phd  service  gender  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service  gender  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
#Reading all the records
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
#Extracting only column names
df.phd
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
# 5     20
# 6     20
# 7     18
# 8     29
# 9     51
# 10    39
# 11    23
# 12     1
# 13    35
# 14    25
# 15    17
# 16     8
# 17     4
# 18    19
# 19    29
# 20     4
# 21    33
# 22     4
# 23     2
# 24    30
# 25    35
# 26    38
# 27    45
# 28     7
# 29    21
# 30     9
# 31    22
# 32    27
# 33    18
# 34    12
# 35    28
# 36    45
# 37    20
# 38     4
# 39    18
# 40    39
# 41    13
# 42     4
# 43     5
# 44    23
# 45    25
# 46    11
# 47    11
# 48    17
# 49    17
# 50    10
# 51    20
# 52    12
# 53     5
# 54    25
# 55     2
# 56    10
# 57     3
# 58    36
# 59    12
# 60     3
# 61    13
# 62    14
# 63    29
# 64    26
# 65    36
# 66     7
# 67    17
# 68     4
# 69    28
# 70     8
# 71    12
# 72    24
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, dtype: int64

# %%
#Selecting Single and Multiple Columns
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df[['rank','gender']]
# Out:
#          rank  gender
# 0        Prof    Male
# 1        Prof    Male
# 2        Prof    Male
# 3        Prof    Male
# 4        Prof    Male
# 5        Prof    Male
# 6   AssocProf    Male
# 7        Prof    Male
# 8        Prof    Male
# 9        Prof    Male
# 10       Prof    Male
# 11       Prof    Male
# 12   AsstProf    Male
# 13       Prof    Male
# 14       Prof    Male
# 15       Prof    Male
# 16   AsstProf    Male
# 17   AsstProf    Male
# 18       Prof    Male
# 19       Prof    Male
# 20   AsstProf    Male
# 21       Prof    Male
# 22   AsstProf    Male
# 23   AsstProf    Male
# 24       Prof    Male
# 25       Prof    Male
# 26       Prof    Male
# 27       Prof    Male
# 28   AsstProf    Male
# 29       Prof    Male
# 30  AssocProf    Male
# 31       Prof    Male
# 32       Prof    Male
# 33       Prof    Male
# 34  AssocProf    Male
# 35       Prof    Male
# 36       Prof    Male
# 37       Prof    Male
# 38   AsstProf    Male
# 39       Prof  Female
# ...

# %%
#Selecting columns with loc and iloc

# %%
#Loc Function
df.loc[18:25,'discipline']
# Out:
# 18    A
# 19    A
# 20    B
# 21    A
# 22    A
# 23    A
# 24    A
# 25    B
# Name: discipline, dtype: object

# %%
df.loc[30:40,'discipline':'service']
# Out:
#    discipline  phd  service
# 30          B    9        7
# 31          B   22       21
# 32          A   27       19
# 33          B   18       18
# 34          B   12        8
# 35          B   28       23
# 36          B   45       45
# 37          A   20        8
# 38          B    4        3
# 39          B   18       18
# 40          A   39       36

# %%
df.iloc[30:40,1:3]
# Out:
#    discipline  phd
# 30          B    9
# 31          B   22
# 32          A   27
# 33          B   18
# 34          B   12
# 35          B   28
# 36          B   45
# 37          A   20
# 38          B    4
# 39          B   18

# %%
#Value Counts
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df['discipline'].unique()
# Out:
# array(['B', 'A'], dtype=object)

# %%
df['gender'].nunique()
# Out:
# 2

# %%
#Renaming column names
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df.rename(columns={'rank':'RANK'},inplace=True)

# %%
df.head()
# Out:
#    RANK discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df.rename(columns={'phd':'PHD'},inplace=True)

# %%
df
# Out:
#          RANK discipline  PHD  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.describe()
# Out:
#              PHD    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.describe().T
# Out:
#          count           mean           std      min       25%       50%  \
# PHD       78.0      19.705128     12.498425      1.0     10.25      18.5
# service   78.0      15.051282     12.139768      0.0      5.25      14.5
# salary    78.0  108023.782051  28293.661022  57800.0  88612.50  104671.0
#
#                75%       max
# PHD          27.75      56.0
# service      20.75      51.0
# salary   126774.75  186960.0
